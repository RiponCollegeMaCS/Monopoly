# %%
import os
os.chdir("C:/Users/Mitchell Eithun/Documents/GitHub/monopoly")

# %%
import pyximport
pyximport.install()
# Out:
# (None, <pyximport.pyximport.PyxImporter at 0x47d6c88>)

# %%
import cmonopoly
# Out:
# ---------------------------------------------------------------------------
# DistutilsPlatformError                    Traceback (most recent call last)
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     208             so_path = build_module(module_name, pyxfilename, pyxbuild_dir,
# --> 209                                    inplace=build_inplace, language_level=language_level)
#     210         mod = imp.load_dynamic(name, so_path)
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyximport.py in build_module(name, pyxfilename, pyxbuild_dir, inplace, language_level)
#     185                                   inplace=inplace,
# --> 186                                   reload_support=pyxargs.reload_support)
#     187     assert os.path.exists(so_path), "Cannot find: %s" % so_path
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyxbuild.py in pyx_to_dll(filename, ext, force_rebuild, build_in_temp, pyxbuild_dir, setup_args, reload_support, inplace)
#      99         obj_build_ext = dist.get_command_obj("build_ext")
# --> 100         dist.run_commands()
#     101         so_path = obj_build_ext.get_outputs()[0]
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\dist.py in run_commands(self)
#     954         for cmd in self.commands:
# --> 955             self.run_command(cmd)
#     956
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\dist.py in run_command(self, command)
#     973         cmd_obj.ensure_finalized()
# --> 974         cmd_obj.run()
#     975         self.have_run[command] = 1
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\Cython\Distutils\build_ext.py in run(self)
#     162
# --> 163         _build_ext.build_ext.run(self)
#     164
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     338         # Now actually compile and link everything.
# --> 339         self.build_extensions()
#     340
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\Cython\Distutils\build_ext.py in build_extensions(self)
#     170             ext.sources = self.cython_sources(ext.sources, ext)
# --> 171             self.build_extension(ext)
#     172
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\command\build_ext.py in build_extension(self, ext)
#     502                                          extra_postargs=extra_args,
# --> 503                                          depends=ext.depends)
#     504
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\msvc9compiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     459         if not self.initialized:
# --> 460             self.initialize()
#     461         compile_info = self._setup_compile(output_dir, macros, include_dirs,
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\msvc9compiler.py in initialize(self, plat_name)
#     370
# --> 371             vc_env = query_vcvarsall(VERSION, plat_spec)
#     372
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\msvc9compiler.py in query_vcvarsall(version, arch)
#     258     if vcvarsall is None:
# --> 259         raise DistutilsPlatformError("Unable to find vcvarsall.bat")
#     260     log.debug("Calling 'vcvarsall.bat %s' (version=%s)", arch, version)
#
# DistutilsPlatformError: Unable to find vcvarsall.bat
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-6999d09295e9> in <module>()
# ----> 1 import cmonopoly
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(self, fullname)
#     429                                  self.pyxbuild_dir,
#     430                                  build_inplace=self.inplace,
# --> 431                                  language_level=self.language_level)
#     432         return module
#     433
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     221             raise ImportError("Building module %s failed: %s" %
#     222                               (name,
# --> 223                                traceback.format_exception_only(*sys.exc_info()[:2]))).with_traceback(sys.exc_info()[2])
#     224     return mod
#     225
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     207                 module_name = name
#     208             so_path = build_module(module_name, pyxfilename, pyxbuild_dir,
# --> 209                                    inplace=build_inplace, language_level=language_level)
#     210         mod = imp.load_dynamic(name, so_path)
#     211         if is_package and not hasattr(mod, '__path__'):
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyximport.py in build_module(name, pyxfilename, pyxbuild_dir, inplace, language_level)
#     184                                   setup_args=sargs,
#     185                                   inplace=inplace,
# --> 186                                   reload_support=pyxargs.reload_support)
#     187     assert os.path.exists(so_path), "Cannot find: %s" % so_path
#     188
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyxbuild.py in pyx_to_dll(filename, ext, force_rebuild, build_in_temp, pyxbuild_dir, setup_args, reload_support, inplace)
#      98     try:
#      99         obj_build_ext = dist.get_command_obj("build_ext")
# --> 100         dist.run_commands()
#     101         so_path = obj_build_ext.get_outputs()[0]
#     102         if obj_build_ext.inplace:
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\dist.py in run_commands(self)
#     953         """
#     954         for cmd in self.commands:
# --> 955             self.run_command(cmd)
#     956
#     957     # -- Methods that operate on its Commands --------------------------
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\dist.py in run_command(self, command)
#     972         cmd_obj = self.get_command_obj(command)
#     973         cmd_obj.ensure_finalized()
# --> 974         cmd_obj.run()
#     975         self.have_run[command] = 1
#     976
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\Cython\Distutils\build_ext.py in run(self)
#     161             optimization.disable_optimization()
#     162
# --> 163         _build_ext.build_ext.run(self)
#     164
#     165     def build_extensions(self):
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     337
#     338         # Now actually compile and link everything.
# --> 339         self.build_extensions()
#     340
#     341     def check_extensions_list(self, extensions):
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\Cython\Distutils\build_ext.py in build_extensions(self)
#     169         for ext in self.extensions:
#     170             ext.sources = self.cython_sources(ext.sources, ext)
# --> 171             self.build_extension(ext)
#     172
#     173     def cython_sources(self, sources, extension):
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\command\build_ext.py in build_extension(self, ext)
#     501                                          debug=self.debug,
#     502                                          extra_postargs=extra_args,
# --> 503                                          depends=ext.depends)
#     504
#     505         # XXX -- this is a Vile HACK!
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\msvc9compiler.py in compile(self, sources, output_dir, macros, include_dirs, debug, extra_preargs, extra_postargs, depends)
#     458
#     459         if not self.initialized:
# --> 460             self.initialize()
#     461         compile_info = self._setup_compile(output_dir, macros, include_dirs,
#     462                                            sources, depends, extra_postargs)
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\msvc9compiler.py in initialize(self, plat_name)
#     369                             PLAT_TO_VCVARS[plat_name]
#     370
# --> 371             vc_env = query_vcvarsall(VERSION, plat_spec)
#     372
#     373             self.__paths = vc_env['path'].split(os.pathsep)
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\msvc9compiler.py in query_vcvarsall(version, arch)
#     257
#     258     if vcvarsall is None:
# --> 259         raise DistutilsPlatformError("Unable to find vcvarsall.bat")
#     260     log.debug("Calling 'vcvarsall.bat %s' (version=%s)", arch, version)
#     261     popen = subprocess.Popen('"%s" %s & set' % (vcvarsall, arch),
#
# ImportError: Building module cmonopoly failed: ['distutils.errors.DistutilsPlatformError: Unable to find vcvarsall.bat\n']

# %%
pyximport.install(setup_args={"script_args":["--compiler=mingw32"]}, reload_support=True)
# Out:
# (None, None)

# %%
import cmonopoly
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     208             so_path = build_module(module_name, pyxfilename, pyxbuild_dir,
# --> 209                                    inplace=build_inplace, language_level=language_level)
#     210         mod = imp.load_dynamic(name, so_path)
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyximport.py in build_module(name, pyxfilename, pyxbuild_dir, inplace, language_level)
#     185                                   inplace=inplace,
# --> 186                                   reload_support=pyxargs.reload_support)
#     187     assert os.path.exists(so_path), "Cannot find: %s" % so_path
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyxbuild.py in pyx_to_dll(filename, ext, force_rebuild, build_in_temp, pyxbuild_dir, setup_args, reload_support, inplace)
#      99         obj_build_ext = dist.get_command_obj("build_ext")
# --> 100         dist.run_commands()
#     101         so_path = obj_build_ext.get_outputs()[0]
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\dist.py in run_commands(self)
#     954         for cmd in self.commands:
# --> 955             self.run_command(cmd)
#     956
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\dist.py in run_command(self, command)
#     973         cmd_obj.ensure_finalized()
# --> 974         cmd_obj.run()
#     975         self.have_run[command] = 1
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\Cython\Distutils\build_ext.py in run(self)
#     162
# --> 163         _build_ext.build_ext.run(self)
#     164
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     307                                      dry_run=self.dry_run,
# --> 308                                      force=self.force)
#     309         customize_compiler(self.compiler)
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\ccompiler.py in new_compiler(plat, compiler, verbose, dry_run, force)
#    1030     # argument.
# -> 1031     return klass(None, dry_run, force)
#    1032
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\cygwinccompiler.py in __init__(self, verbose, dry_run, force)
#     281
# --> 282         CygwinCCompiler.__init__ (self, verbose, dry_run, force)
#     283
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\cygwinccompiler.py in __init__(self, verbose, dry_run, force)
#     125         # dllwrap 2.10.90 is buggy
# --> 126         if self.ld_version >= "2.10.90":
#     127             self.linker_dll = "gcc"
#
# TypeError: unorderable types: NoneType() >= str()
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-6999d09295e9> in <module>()
# ----> 1 import cmonopoly
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(self, fullname)
#     429                                  self.pyxbuild_dir,
#     430                                  build_inplace=self.inplace,
# --> 431                                  language_level=self.language_level)
#     432         return module
#     433
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     221             raise ImportError("Building module %s failed: %s" %
#     222                               (name,
# --> 223                                traceback.format_exception_only(*sys.exc_info()[:2]))).with_traceback(sys.exc_info()[2])
#     224     return mod
#     225
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyximport.py in load_module(name, pyxfilename, pyxbuild_dir, is_package, build_inplace, language_level, so_path)
#     207                 module_name = name
#     208             so_path = build_module(module_name, pyxfilename, pyxbuild_dir,
# --> 209                                    inplace=build_inplace, language_level=language_level)
#     210         mod = imp.load_dynamic(name, so_path)
#     211         if is_package and not hasattr(mod, '__path__'):
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyximport.py in build_module(name, pyxfilename, pyxbuild_dir, inplace, language_level)
#     184                                   setup_args=sargs,
#     185                                   inplace=inplace,
# --> 186                                   reload_support=pyxargs.reload_support)
#     187     assert os.path.exists(so_path), "Cannot find: %s" % so_path
#     188
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\pyximport\pyxbuild.py in pyx_to_dll(filename, ext, force_rebuild, build_in_temp, pyxbuild_dir, setup_args, reload_support, inplace)
#      98     try:
#      99         obj_build_ext = dist.get_command_obj("build_ext")
# --> 100         dist.run_commands()
#     101         so_path = obj_build_ext.get_outputs()[0]
#     102         if obj_build_ext.inplace:
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\dist.py in run_commands(self)
#     953         """
#     954         for cmd in self.commands:
# --> 955             self.run_command(cmd)
#     956
#     957     # -- Methods that operate on its Commands --------------------------
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\dist.py in run_command(self, command)
#     972         cmd_obj = self.get_command_obj(command)
#     973         cmd_obj.ensure_finalized()
# --> 974         cmd_obj.run()
#     975         self.have_run[command] = 1
#     976
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\site-packages\Cython\Distutils\build_ext.py in run(self)
#     161             optimization.disable_optimization()
#     162
# --> 163         _build_ext.build_ext.run(self)
#     164
#     165     def build_extensions(self):
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\command\build_ext.py in run(self)
#     306                                      verbose=self.verbose,
#     307                                      dry_run=self.dry_run,
# --> 308                                      force=self.force)
#     309         customize_compiler(self.compiler)
#     310         # If we are cross-compiling, init the compiler now (if we are not
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\ccompiler.py in new_compiler(plat, compiler, verbose, dry_run, force)
#    1029     # with classes that expect verbose to be the first positional
#    1030     # argument.
# -> 1031     return klass(None, dry_run, force)
#    1032
#    1033
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\cygwinccompiler.py in __init__(self, verbose, dry_run, force)
#     280     def __init__(self, verbose=0, dry_run=0, force=0):
#     281
# --> 282         CygwinCCompiler.__init__ (self, verbose, dry_run, force)
#     283
#     284         # ld_version >= "2.13" support -shared so use it instead of
#
# C:\Users\Mitchell Eithun\Anaconda3\lib\distutils\cygwinccompiler.py in __init__(self, verbose, dry_run, force)
#     124         # same as the rest of binutils ( also ld )
#     125         # dllwrap 2.10.90 is buggy
# --> 126         if self.ld_version >= "2.10.90":
#     127             self.linker_dll = "gcc"
#     128         else:
#
# ImportError: Building module cmonopoly failed: ['TypeError: unorderable types: NoneType() >= str()\n']
